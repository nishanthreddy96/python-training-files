# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
age_axis  = [21,45,65,73,76,87]

sal_axis = [0,2,4,5,6,8]

del_axis = [1,2,5,3,7,8]

sim_axis = [4,5,2,8,4,8]

plt.plot(age_axis,sim_axis, label = 'Sim')
plt.plot(age_axis,del_axis, label = 'Age')
plt.plot(age_axis, sal_axis, label = 'Salary')
plt.legend()

# %%
sam_read = pd.read_csv("sample_data.csv")
plt.plot(sam_read)
plt.xlabel('No_of_products')
plt.ylabel('Sales')
plt.title("Company with number of products and their Sales")
# Out:
# Text(0.5, 1.0, 'Company with number of products and their Sales')

# %%
sam_read = pd.read_csv("sample_data.csv")
plt.plot(sam_read)
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title("Company Sales for the Year")
plt.legend(['Year','Sales'])

# %%
sam_read = pd.read_csv("sample_data1.txt")
plt.plot(sam_read)
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title("Company Sales for the Year")
# Out:
# Text(0.5, 1.0, 'Company Sales for the Year')

# %%
py_ages = [43,40,55,23,37,45,46,29,12,5,7,4,10]
# Ages below 21 cannot have salary so we need to remove ages below 18
py_sal = [2100,5000,2700,7200,2190,5600,6600,4742,6765,1753,7501,3201,2301]
ar_ages = np.sort(py_ages)
ar_sal = np.sort(py_sal)
print(ar_ages)
print(ar_sal)
plt.plot(py_ages,py_sal) #secondary or 2nd comparison is assigned to orange
# Out:
# [ 4  5  7 10 12 23 29 37 40 43 45 46 55]
# [1753 2100 2190 2301 2700 3201 4742 5000 5600 6600 6765 7200 7501]

# %%
# after sorting
plt.plot(ar_ages,ar_sal) # primary or 1st comparison is assigned to blue

# %%
l_ages = []
for i in ar_ages:
    if i>21:
        l_ages.append(i)        
    else:
        pass
print(l_ages)
# Out:
# [23, 29, 37, 40, 43, 45, 46, 55]

# %%
l_sal = []
for i in ar_sal:
    if i> 3000:
        l_sal.append(i)
       # print(i, end = ' ')
    else:
        pass
print(l_sal)
# Out:
# [3201, 4742, 5000, 5600, 6600, 6765, 7200, 7501]

# %%
plt.plot(l_ages,l_sal)
plt.xlabel("Ages")
plt.ylabel('Salary')
plt.title("Comparing Ages with Salaries")
# Out:
# Text(0.5, 1.0, 'Comparing Ages with Salaries')

# %%
py_iq = [5,2,4,6,4,5,3,4]
plt.plot(l_ages,py_iq)
plt.title('Ages and IQ levels of Employee ')

plt.xlabel('Ages')
plt.ylabel("Employee IQ")
# Out:
# Text(0, 0.5, 'Employee IQ')
