# %%
import pandas as pd
import numpy as np
import sys

# %%
np.set_printoptions(threshold = sys.maxsize)

# %%
in_count = np.loadtxt("country-capitals.csv",delimiter = ',',dtype = str)
df = pd.DataFrame(in_count)
print(df.to_string())
# Out:
#                                             0                    1                     2                 3            4                5
# 0                              ï»¿CountryName          CapitalName       CapitalLatitude  CapitalLongitude  CountryCode    ContinentName
# 1                                  Somaliland             Hargeisa                  9.55         44.050000         NULL           Africa
# 2    South Georgia and South Sandwich Islands    King Edward Point            -54.283333        -36.500000           GS       Antarctica
# 3         French Southern and Antarctic Lands   Port-aux-FranÃ§ais                -49.35         70.216667           TF       Antarctica
# 4                                   Palestine            Jerusalem    31.766666666666666         35.233333           PS             Asia
# 5                               Aland Islands            Mariehamn             60.116667         19.900000           AX           Europe
# ...

# %%
in_var = pd.read_csv('country-capitals.csv')
in_var.head()
# Out:
#                                 CountryName        CapitalName  \
# 0                                Somaliland           Hargeisa
# 1  South Georgia and South Sandwich Islands  King Edward Point
# 2       French Southern and Antarctic Lands  Port-aux-Français
# 3                                 Palestine          Jerusalem
# 4                             Aland Islands          Mariehamn
#
#    CapitalLatitude  CapitalLongitude CountryCode ContinentName
# 0         9.550000         44.050000         NaN        Africa
# 1       -54.283333        -36.500000          GS    Antarctica
# 2       -49.350000         70.216667          TF    Antarctica
# 3        31.766667         35.233333          PS          Asia
# 4        60.116667         19.900000          AX        Europe

# %%
in_var.drop(['CapitalLatitude','CapitalLongitude','ContinentName'],axis = 1,inplace = True)

# %%
print(in_var)
# Out:
#                                   CountryName        CapitalName CountryCode
# 0                                  Somaliland           Hargeisa         NaN
# 1    South Georgia and South Sandwich Islands  King Edward Point          GS
# 2         French Southern and Antarctic Lands  Port-aux-Français          TF
# 3                                   Palestine          Jerusalem          PS
# 4                               Aland Islands          Mariehamn          AX
# 5                                       Nauru              Yaren          NR
# 6                                Saint Martin            Marigot          MF
# 7                                     Tokelau              Atafu          TK
# 8                              Western Sahara           El-Aaiún          EH
# 9                                 Afghanistan              Kabul          AF
# 10                                    Albania             Tirana          AL
# ...

# %%
#for column
#in_var['column'] = df['column'].replace(np.nan,0)

#for whole dataframe
in_var = in_var.replace(np.nan,0)

# %%
np.set_printoptions(threshold = sys.maxsize)

print(in_var[:30])
# Out:
#                                  CountryName        CapitalName CountryCode
# 0                                 Somaliland           Hargeisa           0
# 1   South Georgia and South Sandwich Islands  King Edward Point          GS
# 2        French Southern and Antarctic Lands  Port-aux-Français          TF
# 3                                  Palestine          Jerusalem          PS
# 4                              Aland Islands          Mariehamn          AX
# 5                                      Nauru              Yaren          NR
# 6                               Saint Martin            Marigot          MF
# 7                                    Tokelau              Atafu          TK
# 8                             Western Sahara           El-Aaiún          EH
# 9                                Afghanistan              Kabul          AF
# 10                                   Albania             Tirana          AL
# ...

# %%
in_var = np.array(in_var[:])
print(in_var)
# Out:
# [['Somaliland' 'Hargeisa' 0]
#  ['South Georgia and South Sandwich Islands' 'King Edward Point' 'GS']
#  ['French Southern and Antarctic Lands' 'Port-aux-Français' 'TF']
#  ['Palestine' 'Jerusalem' 'PS']
#  ['Aland Islands' 'Mariehamn' 'AX']
#  ['Nauru' 'Yaren' 'NR']
#  ['Saint Martin' 'Marigot' 'MF']
#  ['Tokelau' 'Atafu' 'TK']
#  ['Western Sahara' 'El-Aaiún' 'EH']
#  ['Afghanistan' 'Kabul' 'AF']
#  ['Albania' 'Tirana' 'AL']
#  ['Algeria' 'Algiers' 'DZ']
#  ['American Samoa' 'Pago Pago' 'AS']
#  ['Andorra' 'Andorra la Vella' 'AD']
#  ['Angola' 'Luanda' 'AO']
#  ['Anguilla' 'The Valley' 'AI']
#  ['Antigua and Barbuda' "Saint John's" 'AG']
#  ['Argentina' 'Buenos Aires' 'AR']
#  ['Armenia' 'Yerevan' 'AM']
#  ['Aruba' 'Oranjestad' 'AW']
#  ['Australia' 'Canberra' 'AU']
#  ['Austria' 'Vienna' 'AT']
#  ['Azerbaijan' 'Baku' 'AZ']
#  ['Bahamas' 'Nassau' 'BS']
#  ['Bahrain' 'Manama' 'BH']
#  ['Bangladesh' 'Dhaka' 'BD']
#  ['Barbados' 'Bridgetown' 'BB']
#  ['Belarus' 'Minsk' 'BY']
# ...

# %%
in_var.shape
# Out:
# (245, 3)
